# %%
#%%

#zipline --start=2011-1-1 --end=2013-1-1 --no-benchmark

from   zipline.api       import order, record, symbol, set_benchmark
from   zipline           import run_algorithm
import pandas            as pd
import numpy             as np
import matplotlib.pyplot as plt

# %%
#%%

def initialize(context):
    pass

def handle_data(context, data):
    order(symbol('AAPL'), 10)
    record(AAPL=data.current(symbol('AAPL'), "price"))
    
def analyze(context, perf):
    ax1 = plt.subplot(211)
    perf.portfolio_value.plot(ax=ax1)
    ax2 = plt.subplot(212, sharex=ax1)
    perf.AAPL.plot(ax=ax2)
    plt.gcf().set_size_inches(18, 8)
    plt.show()

# %%
#%%

start_date   = pd.Timestamp('2011-1-1', tz='utc')
end_date     = pd.Timestamp('2013-1-1', tz='utc')
capital_base = 10000

# %%
#%%

start_date   = pd.Timestamp('2011-1-1')
end_date     = pd.Timestamp('2013-1-1')
capital_base = 10000

result = run_algorithm(
    start          = start_date,
    end            = end_date,
    initialize     = initialize,
    handle_data    = handle_data,
    analyze        = analyze,
    capital_base   = capital_base,
    data_frequency = 'daily',
    bundle         = 'norgatedata-sp500'
)
# Out:
# c:\src\dev\ziplinereloaded-norgate-exps\env\lib\site-packages\zipline\finance\ledger.py:424: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   self.daily_returns_series[session_ix] = self.todays_returns

# %%
#%%

result
# Out:
#                                         period_open              period_close  \
# 2011-01-03 21:00:00+00:00 2011-01-03 14:31:00+00:00 2011-01-03 21:00:00+00:00
# 2011-01-04 21:00:00+00:00 2011-01-04 14:31:00+00:00 2011-01-04 21:00:00+00:00
# 2011-01-05 21:00:00+00:00 2011-01-05 14:31:00+00:00 2011-01-05 21:00:00+00:00
# 2011-01-06 21:00:00+00:00 2011-01-06 14:31:00+00:00 2011-01-06 21:00:00+00:00
# 2011-01-07 21:00:00+00:00 2011-01-07 14:31:00+00:00 2011-01-07 21:00:00+00:00
# ...                                             ...                       ...
# 2012-12-24 18:00:00+00:00 2012-12-24 14:31:00+00:00 2012-12-24 18:00:00+00:00
# 2012-12-26 21:00:00+00:00 2012-12-26 14:31:00+00:00 2012-12-26 21:00:00+00:00
# 2012-12-27 21:00:00+00:00 2012-12-27 14:31:00+00:00 2012-12-27 21:00:00+00:00
# 2012-12-28 21:00:00+00:00 2012-12-28 14:31:00+00:00 2012-12-28 21:00:00+00:00
# 2012-12-31 21:00:00+00:00 2012-12-31 14:31:00+00:00 2012-12-31 21:00:00+00:00
#
#                            long_value  long_exposure  longs_count  \
# 2011-01-03 21:00:00+00:00        0.00           0.00            0
# 2011-01-04 21:00:00+00:00      100.03         100.03            1
# 2011-01-05 21:00:00+00:00      201.70         201.70            1
# 2011-01-06 21:00:00+00:00      302.31         302.31            1
# 2011-01-07 21:00:00+00:00      405.96         405.96            1
# ...                               ...            ...          ...
# 2012-12-24 18:00:00+00:00    78754.62       78754.62            1
# 2011-01-06 21:00:00+00:00            0.0             4      0.030230
# 2011-01-07 21:00:00+00:00            0.0             5      0.040586
# ...                                  ...           ...           ...
# 2012-12-24 18:00:00+00:00            0.0           498      4.590141
# 2012-12-26 21:00:00+00:00            0.0           499      4.590141
# 2012-12-27 21:00:00+00:00            0.0           500      4.590141
# 2012-12-28 21:00:00+00:00            0.0           501      4.688878
# 2012-12-31 21:00:00+00:00            0.0           502      4.688878
#
#                           benchmark_period_return  benchmark_volatility  \
# 2011-01-03 21:00:00+00:00                     0.0                   NaN
# 2011-01-04 21:00:00+00:00                     0.0                   0.0
# 2011-01-05 21:00:00+00:00                     0.0                   0.0
# 2011-01-06 21:00:00+00:00                     0.0                   0.0
# 2011-01-07 21:00:00+00:00                     0.0                   0.0
# ...                                           ...                   ...
# 2012-12-24 18:00:00+00:00                     0.0                   0.0
# 2012-12-26 21:00:00+00:00                     0.0                   0.0
# 2012-12-27 21:00:00+00:00                     0.0                   0.0
# 2012-12-28 21:00:00+00:00                     0.0                   0.0
# 2012-12-31 21:00:00+00:00                     0.0                   0.0
#
#                           algorithm_period_return
# 2011-01-03 21:00:00+00:00                0.000000
# 2011-01-04 21:00:00+00:00               -0.000006
# 2011-01-05 21:00:00+00:00                0.000070
# 2011-01-06 21:00:00+00:00                0.000048
# 2011-01-07 21:00:00+00:00                0.000258
# ...                                           ...
# 2012-12-24 18:00:00+00:00                0.815736
# 2012-12-26 21:00:00+00:00                0.706884
# 2012-12-27 21:00:00+00:00                0.738249
# 2012-12-28 21:00:00+00:00                0.655407
# 2012-12-31 21:00:00+00:00                0.998898
#
# [502 rows x 38 columns]

# %%
#%%

result['sharpe'].plot()
# Out:
# <Axes: >

# %%
#%%

list(result.keys())
# Out:
# ['period_open',
#  'period_close',
#  'long_value',
#  'long_exposure',
#  'longs_count',
#  'ending_cash',
#  'short_exposure',
#  'gross_leverage',
#  'net_leverage',
#  'short_value',
#  'portfolio_value',
#  'starting_exposure',
#  'ending_value',
#  'ending_exposure',
#  'starting_cash',
#  'shorts_count',
#  'capital_used',
#  'transactions',
#  'starting_value',
#  'positions',
#  'orders',
#  'pnl',
#  'returns',
#  'AAPL',
#  'algo_volatility',
#  'treasury_period_return',
#  'alpha',
#  'beta',
#  'sharpe',
#  'max_drawdown',
#  'sortino',
#  'period_label',
#  'excess_return',
#  'trading_days',
#  'max_leverage',
#  'benchmark_period_return',
#  'benchmark_volatility',
#  'algorithm_period_return']

# %%
#%%

result['max_drawdown'].plot()
# Out:
# <Axes: >

# %%
#%%

result['capital_used'].plot()
# Out:
# <Axes: >

# %%
#%%

result['returns'].plot()
# Out:
# <Axes: >

# %%
#%%

result['returns'].cumsum().plot()
# Out:
# <Axes: >
